# %%
import pickle
import os
from utils import plot_dendogram_and_tsne

import sys
sys.path.append('..')

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Get Hiddens

# %%
path = os.path.join('..', 'data', 'hidden_states', 'english_lstm_300_seq_len_32.pkl')

with open(os.path.join(path), 'rb') as f:
    hiddens = pickle.load(f)

# %%
plot_dendogram_and_tsne(hiddens, 'English')
# Out:
# Variance PCA: 0.8913281559944153
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 832 samples in 0.003s...
# [t-SNE] Computed neighbors for 832 samples in 0.123s...
# [t-SNE] Computed conditional probabilities for sample 832 / 832
# [t-SNE] Mean sigma: 2.200001
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.164474
# [t-SNE] KL divergence after 1000 iterations: 0.711720
