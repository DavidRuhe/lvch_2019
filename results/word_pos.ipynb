# %%
import pickle
import os
from utils import plot_dendogram_and_tsne

import sys
sys.path.append('..')

# %load_ext autoreload
# %autoreload 2

# %%
path = os.path.join('..', 'data', 'hidden_states', 'word_pos_lstm_256_seq_len_32.pkl')

with open(os.path.join(path), 'rb') as f:
    hiddens = pickle.load(f)

plot_dendogram_and_tsne(hiddens, 'Word POS', pca_components=128)
# Out:
# Variance PCA: 0.9073500633239746
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 768 samples in 0.005s...
# [t-SNE] Computed neighbors for 768 samples in 0.157s...
# [t-SNE] Computed conditional probabilities for sample 768 / 768
# [t-SNE] Mean sigma: 1.893684
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.831944
# [t-SNE] KL divergence after 1000 iterations: 0.492223
